# %% [markdown]
# # Communicating Results Quiz
# Now let's answer the same questions found in "Drawing Conclusions Quiz" using visualizations.\
# Using the grocery store dataset `store_data.csv` , create plots with appropriate labeling, colors and size to communicate the results of the following questions.
#
# Which store has the highest total sales for the last month?\  (store B)
# Which store makes the most sales on average?\  (store B)
# Which store sells the most during the week of March 13th, 2016?\  (store D)
# Which store has the most sales in the latest 3-month period?\  (store A)
# **Which store is the most consistent ? (important)**  (store D)

# %%
# import and load the data
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('store_data.csv')

# %%
# explore the data (use plots only)
# df.plot(kind='kde')
# df.plot(kind='bar')
df.plot(kind='hist', figsize = (8,8))
plt.show()

# %%
# plot sales for the last month
df['week'] = pd.to_datetime(df['week'])

last_month_sales = df[df['week'] >= df['week'].max() - pd.DateOffset(months = 1)].sum()
last_month_sales.plot(kind='bar')
plt.show()
# last_month_sales
# Out:
# C:\Users\ELmohannd\AppData\Local\Temp\ipykernel_17956\49408707.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   last_month_sales = df[df['week'] >= df['week'].max() - pd.DateOffset(months = 1)].sum()

# %%
# plot average sales
avg = df.iloc[:, 1:].mean()
avg.plot(kind='bar')
plt.show()

# %%
# plot sales for the week of March 13th, 2016
df['week'] = pd.to_datetime(df['week'])
dtime = pd.to_datetime('2016-03-13')
temp = df[df['week'] == dtime]
place = df.iloc[97]
place[1:].plot(kind='bar')
plt.show()

# %%
# plot sales for the lastest 3-month periods
df['week'] = pd.to_datetime(df['week'])

last_month_sales = df[df['week'] >= df['week'].max() - pd.DateOffset(months = 3)].sum()
last_month_sales.plot(kind='bar')
plt.show()
# Out:
# C:\Users\ELmohannd\AppData\Local\Temp\ipykernel_17956\877253819.py:4: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   last_month_sales = df[df['week'] >= df['week'].max() - pd.DateOffset(months = 3)].sum()
