# %% [markdown]
# # EDA with Visuals
# Create visualizations to answer the questions below. Use the `winequality_edited.csv` dataset, which you should've created  in the previous quiz.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('winequality_edited.csv')
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %% [markdown]
# ### Which of the following feature variables appear skewed to the right? Fixed Acidity, Total Sulfur Dioxide, pH, Alcohol     (pH)    (answer using plots)

# %%
# df['fixed_acidity'].plot(kind='kde')
# df['pH'].plot(kind='kde')
# df['total_sulfur_dioxide'].plot(kind='kde')
# df['alcohol'].plot(kind='kde')
df_skew = df.loc[:, ['fixed_acidity', 'pH', 'total_sulfur_dioxide', 'alcohol']]
df_skew.plot(kind='kde')
plt.xlim(-20, 50)
plt.ylim(0, 0.01)
# Out:
# (0.0, 0.01)

# %% [markdown]
# ### Which of the following is most likely to have a positive impact on quality? Volatile Acidity, Residual Sugar, pH, Alcohol      (residual_sugar)     (answer using plots)

# %%
df.plot(x = "quality", y = 'volatile_acidity', kind = "scatter")
plt.show()

# %%
df.plot(x = "quality", y = 'residual_sugar', kind = "scatter")
plt.show()
# plt.ylim(0, 20)

# %%
df.plot(x = "quality", y = 'pH', kind = "scatter")
plt.show()

# %%
df.plot(x = "quality", y = 'alcohol', kind = "scatter")
plt.show()
